# %%
import extruct
import numpy as np
import matplotlib.pyplot as plt
help(extruct)
# Out:
# Help on module extruct:
#
# NAME
#     extruct
#
# CLASSES
#     pybind11_builtins.pybind11_object(builtins.object)
#         Background
#         Measurement
#             PowerSpectrumObs
#         Multiverse
#         PowerSpectrum
#             PowerLaw
#
#     class Background(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      Background
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: extruct.Background) -> None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class Measurement(pybind11_builtins.pybind11_object)
# ...

# %%
god = extruct.Multiverse()

pspec = extruct.PowerSpectrum()
bg = extruct.Background()
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec))
print(god.bang(10, bg, pspec))
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
god.evolveAll(3.3)

# %%
bg

# %%
print(god.bang(10, bg, pspec))
# Out:
# 3

# %%
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec)) 
print(god.bang(10, bg, pspec))
